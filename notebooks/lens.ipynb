# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import json
input_file = open ('data.json')
json_array = json.load(input_file)

# %%
tile = np.array(json_array).reshape((312,312 ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/swarchol/Research/psudo/notebooks/lens.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/swarchol/Research/psudo/notebooks/lens.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> tile = np.array(json_array).reshape((312,312 ))
#
# ValueError: cannot reshape array of size 60528 into shape (312,312)

# %%
149*149
# Out:
# 22201

# %%
plt.imshow(tile)
